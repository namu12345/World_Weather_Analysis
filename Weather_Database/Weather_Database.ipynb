# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 100 for logging purposes.
    if (i % 100 == 0 and i >= 100):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
 
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_data = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_data,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | fare
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | vila velha
# Processing Record 6 of Set 1 | anupgarh
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | shitanjing
# Processing Record 13 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | itoman
# Processing Record 17 of Set 1 | husavik
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | conde
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | saint-georges
# Processing Record 25 of Set 1 | mount isa
# Processing Record 26 of Set 1 | ulaangom
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | prince rupert
# Processing Record 29 of Set 1 | alice springs
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | nago
# Processing Record 33 of Set 1 | moose factory
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | lerik
# Processing Record 43 of Set 1 | riyadh
# Processing Record 44 of Set 1 | rokytne
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | alice
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | saint-pierre
# Processing Record 51 of Set 1 | hilo
# Processing Record 52 of Set 1 | tari
# Processing Record 53 of Set 1 | bimbo
# Processing Record 54 of Set 1 | chicama
# Processing Record 55 of Set 1 | ostrovnoy
# Processing Record 56 of Set 1 | bonthe
# Processing Record 57 of Set 1 | lagoa
# Processing Record 58 of Set 1 | beyneu
# Processing Record 59 of Set 1 | port elizabeth
# Processing Record 60 of Set 1 | susangerd
# Processing Record 61 of Set 1 | asau
# Processing Record 62 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 63 of Set 1 | mataura
# Processing Record 64 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 65 of Set 1 | shenjiamen
# Processing Record 66 of Set 1 | siutu
# City not found. Skipping...
# Processing Record 67 of Set 1 | devonport
# Processing Record 68 of Set 1 | kupang
# Processing Record 69 of Set 1 | axim
# Processing Record 70 of Set 1 | voh
# Processing Record 71 of Set 1 | sioux lookout
# Processing Record 72 of Set 1 | port hardy
# Processing Record 73 of Set 1 | vardo
# Processing Record 74 of Set 1 | yellowknife
# Processing Record 75 of Set 1 | lasa
# Processing Record 76 of Set 1 | tiksi
# Processing Record 77 of Set 1 | kapaa
# Processing Record 78 of Set 1 | yaring
# Processing Record 79 of Set 1 | svetlaya
# Processing Record 80 of Set 1 | katubao
# Processing Record 81 of Set 1 | sidi bu zayd
# City not found. Skipping...
# Processing Record 82 of Set 1 | arlit
# Processing Record 83 of Set 1 | cabo san lucas
# Processing Record 84 of Set 1 | kahului
# Processing Record 85 of Set 1 | lana
# Processing Record 86 of Set 1 | beringovskiy
# Processing Record 87 of Set 1 | ixtapa
# Processing Record 88 of Set 1 | punta arenas
# Processing Record 89 of Set 1 | sitka
# Processing Record 90 of Set 1 | mayo
# Processing Record 91 of Set 1 | vila franca do campo
# Processing Record 92 of Set 1 | tilichiki
# Processing Record 93 of Set 1 | pisco
# Processing Record 94 of Set 1 | norman wells
# Processing Record 95 of Set 1 | salalah
# Processing Record 96 of Set 1 | soyaux
# Processing Record 97 of Set 1 | puerto ayacucho
# Processing Record 98 of Set 1 | acapulco
# Processing Record 99 of Set 1 | dingle
# Processing Record 100 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 2 | srivardhan
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | angoram
# Processing Record 6 of Set 2 | hervey bay
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | tual
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | luau
# Processing Record 13 of Set 2 | sao joao da barra
# Processing Record 14 of Set 2 | rawson
# Processing Record 15 of Set 2 | ejido
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 18 of Set 2 | kabanjahe
# Processing Record 19 of Set 2 | ubinskoye
# Processing Record 20 of Set 2 | vangaindrano
# Processing Record 21 of Set 2 | north battleford
# Processing Record 22 of Set 2 | mtwara
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | sheridan
# Processing Record 25 of Set 2 | ponnani
# Processing Record 26 of Set 2 | rocha
# Processing Record 27 of Set 2 | alugan
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | marawi
# Processing Record 30 of Set 2 | nouakchott
# Processing Record 31 of Set 2 | svetlogorsk
# Processing Record 32 of Set 2 | trairi
# Processing Record 33 of Set 2 | ayr
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | havre-saint-pierre
# Processing Record 36 of Set 2 | mbaiki
# Processing Record 37 of Set 2 | itupiranga
# Processing Record 38 of Set 2 | sitges
# Processing Record 39 of Set 2 | mosquera
# Processing Record 40 of Set 2 | atambua
# Processing Record 41 of Set 2 | caruray
# Processing Record 42 of Set 2 | viedma
# Processing Record 43 of Set 2 | abiy adi
# City not found. Skipping...
# Processing Record 44 of Set 2 | comodoro rivadavia
# Processing Record 45 of Set 2 | awjilah
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | sinnamary
# Processing Record 48 of Set 2 | nishihara
# Processing Record 49 of Set 2 | sicuani
# Processing Record 50 of Set 2 | santo anastacio
# Processing Record 51 of Set 2 | saint anthony
# Processing Record 52 of Set 2 | bambous virieux
# Processing Record 53 of Set 2 | makurdi
# Processing Record 54 of Set 2 | castro
# Processing Record 55 of Set 2 | megion
# Processing Record 56 of Set 2 | santa cruz
# Processing Record 57 of Set 2 | gazli
# Processing Record 58 of Set 2 | geraldton
# Processing Record 59 of Set 2 | flinders
# Processing Record 60 of Set 2 | provideniya
# Processing Record 61 of Set 2 | tlaxiaco
# City not found. Skipping...
# Processing Record 62 of Set 2 | vitoria da conquista
# Processing Record 63 of Set 2 | carnarvon
# Processing Record 64 of Set 2 | tambacounda
# Processing Record 65 of Set 2 | tasiilaq
# Processing Record 66 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 67 of Set 2 | hay river
# Processing Record 68 of Set 2 | capim grosso
# Processing Record 69 of Set 2 | saint george
# Processing Record 70 of Set 2 | lompoc
# Processing Record 71 of Set 2 | caravelas
# Processing Record 72 of Set 2 | ouango
# Processing Record 73 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 74 of Set 2 | la cruz
# Processing Record 75 of Set 2 | soyo
# Processing Record 76 of Set 2 | saint-paul
# Processing Record 77 of Set 2 | nome
# Processing Record 78 of Set 2 | nikolskoye
# Processing Record 79 of Set 2 | pevek
# Processing Record 80 of Set 2 | lebu
# Processing Record 81 of Set 2 | ajdabiya
# Processing Record 82 of Set 2 | pechora
# Processing Record 83 of Set 2 | onalaska
# Processing Record 84 of Set 2 | olafsvik
# Processing Record 85 of Set 2 | aksu
# Processing Record 86 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 87 of Set 2 | zhigansk
# Processing Record 88 of Set 2 | cordoba
# Processing Record 89 of Set 2 | eskisehir
# Processing Record 90 of Set 2 | harper
# Processing Record 91 of Set 2 | araguacu
# Processing Record 92 of Set 2 | valparaiso
# Processing Record 93 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 94 of Set 2 | namibe
# Processing Record 95 of Set 2 | coquimbo
# Processing Record 96 of Set 2 | florence
# Processing Record 97 of Set 2 | nizhnevartovsk
# Processing Record 98 of Set 2 | candabong
# Processing Record 99 of Set 2 | kieta
# Processing Record 100 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | sakata
# Processing Record 2 of Set 3 | tonshayevo
# Processing Record 3 of Set 3 | ugoofaaru
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | north platte
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | solnechnyy
# Processing Record 8 of Set 3 | pangnirtung
# Processing Record 9 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | varnavino
# Processing Record 12 of Set 3 | naantali
# Processing Record 13 of Set 3 | kaeo
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | mount gambier
# Processing Record 16 of Set 3 | iquitos
# Processing Record 17 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 3 | nikki
# Processing Record 19 of Set 3 | ereymentau
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | apatity
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | richards bay
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | vieira de leiria
# Processing Record 26 of Set 3 | adrar
# Processing Record 27 of Set 3 | llanes
# Processing Record 28 of Set 3 | lucapa
# Processing Record 29 of Set 3 | cherskiy
# Processing Record 30 of Set 3 | lulea
# Processing Record 31 of Set 3 | kintampo
# Processing Record 32 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 3 | anadyr
# Processing Record 34 of Set 3 | umm kaddadah
# Processing Record 35 of Set 3 | khuzdar
# Processing Record 36 of Set 3 | ambulu
# Processing Record 37 of Set 3 | broome
# Processing Record 38 of Set 3 | yate
# Processing Record 39 of Set 3 | nhulunbuy
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | balkanabat
# Processing Record 42 of Set 3 | nabire
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | chaman
# Processing Record 46 of Set 3 | manzhouli
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 49 of Set 3 | krasnoshchekovo
# Processing Record 50 of Set 3 | savinka
# Processing Record 51 of Set 3 | chernyshevskiy
# Processing Record 52 of Set 3 | zhanakorgan
# Processing Record 53 of Set 3 | arona
# Processing Record 54 of Set 3 | tuatapere
# Processing Record 55 of Set 3 | ialibu
# Processing Record 56 of Set 3 | victoria
# Processing Record 57 of Set 3 | marsabit
# Processing Record 58 of Set 3 | islahiye
# Processing Record 59 of Set 3 | brazzaville
# Processing Record 60 of Set 3 | qaanaaq
# Processing Record 61 of Set 3 | pacific grove
# Processing Record 62 of Set 3 | dapdap
# Processing Record 63 of Set 3 | mar del plata
# Processing Record 64 of Set 3 | taizhou
# Processing Record 65 of Set 3 | chokurdakh
# Processing Record 66 of Set 3 | tautira
# Processing Record 67 of Set 3 | mercedes
# Processing Record 68 of Set 3 | saskylakh
# Processing Record 69 of Set 3 | billings
# Processing Record 70 of Set 3 | hualmay
# Processing Record 71 of Set 3 | ordzhonikidze
# Processing Record 72 of Set 3 | batticaloa
# Processing Record 73 of Set 3 | denpasar
# Processing Record 74 of Set 3 | omboue
# Processing Record 75 of Set 3 | pangody
# Processing Record 76 of Set 3 | atasu
# Processing Record 77 of Set 3 | longyearbyen
# Processing Record 78 of Set 3 | port-cartier
# Processing Record 79 of Set 3 | san patricio
# Processing Record 80 of Set 3 | isabela
# Processing Record 81 of Set 3 | eureka
# Processing Record 82 of Set 3 | faanui
# Processing Record 83 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 84 of Set 3 | tymovskoye
# Processing Record 85 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 86 of Set 3 | atakpame
# Processing Record 87 of Set 3 | vaitape
# Processing Record 88 of Set 3 | baghdad
# Processing Record 89 of Set 3 | kikwit
# Processing Record 90 of Set 3 | kisangani
# Processing Record 91 of Set 3 | hobyo
# Processing Record 92 of Set 3 | sao filipe
# Processing Record 93 of Set 3 | lavrentiya
# Processing Record 94 of Set 3 | severobaykalsk
# Processing Record 95 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 96 of Set 3 | mocuba
# Processing Record 97 of Set 3 | arawa
# Processing Record 98 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 99 of Set 3 | bay roberts
# Processing Record 100 of Set 3 | sao miguel do araguaia
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | mandalgovi
# Processing Record 3 of Set 4 | dawlatabad
# Processing Record 4 of Set 4 | ahipara
# Processing Record 5 of Set 4 | yeppoon
# Processing Record 6 of Set 4 | cuamba
# Processing Record 7 of Set 4 | talaya
# Processing Record 8 of Set 4 | derzhavinsk
# Processing Record 9 of Set 4 | galeana
# Processing Record 10 of Set 4 | makakilo city
# Processing Record 11 of Set 4 | kharan
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | alofi
# Processing Record 14 of Set 4 | karratha
# Processing Record 15 of Set 4 | namatanai
# Processing Record 16 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 17 of Set 4 | verkhniy avzyan
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | port hedland
# Processing Record 20 of Set 4 | grand-lahou
# Processing Record 21 of Set 4 | quang ngai
# Processing Record 22 of Set 4 | guerrero negro
# Processing Record 23 of Set 4 | phonhong
# Processing Record 24 of Set 4 | winslow
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | georgetown
# Processing Record 27 of Set 4 | guarapari
# Processing Record 28 of Set 4 | kutum
# Processing Record 29 of Set 4 | ballina
# Processing Record 30 of Set 4 | balkhash
# Processing Record 31 of Set 4 | miramar
# Processing Record 32 of Set 4 | hegra
# Processing Record 33 of Set 4 | cockburn town
# Processing Record 34 of Set 4 | wellington
# Processing Record 35 of Set 4 | road town
# Processing Record 36 of Set 4 | zermatt
# Processing Record 37 of Set 4 | pitiquito
# Processing Record 38 of Set 4 | skibbereen
# Processing Record 39 of Set 4 | ceres
# Processing Record 40 of Set 4 | dunedin
# Processing Record 41 of Set 4 | lodwar
# Processing Record 42 of Set 4 | tashtyp
# Processing Record 43 of Set 4 | peniche
# Processing Record 44 of Set 4 | puerto baquerizo moreno
# Processing Record 45 of Set 4 | paamiut
# Processing Record 46 of Set 4 | muroto
# Processing Record 47 of Set 4 | maarianhamina
# Processing Record 48 of Set 4 | visby
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 50 of Set 4 | ciudad bolivar
# Processing Record 51 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 52 of Set 4 | morgan city
# Processing Record 53 of Set 4 | la orilla
# Processing Record 54 of Set 4 | xichang
# Processing Record 55 of Set 4 | okhotsk
# Processing Record 56 of Set 4 | cayenne
# Processing Record 57 of Set 4 | dawson creek
# Processing Record 58 of Set 4 | uppsala
# Processing Record 59 of Set 4 | monze
# Processing Record 60 of Set 4 | phuthaditjhaba
# Processing Record 61 of Set 4 | moen
# Processing Record 62 of Set 4 | evensk
# Processing Record 63 of Set 4 | portland
# Processing Record 64 of Set 4 | katsuura
# Processing Record 65 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 66 of Set 4 | kavieng
# Processing Record 67 of Set 4 | stykkisholmur
# Processing Record 68 of Set 4 | khandagayty
# Processing Record 69 of Set 4 | murgab
# Processing Record 70 of Set 4 | bambanglipuro
# Processing Record 71 of Set 4 | bathurst
# Processing Record 72 of Set 4 | laguna
# Processing Record 73 of Set 4 | semey
# Processing Record 74 of Set 4 | gazojak
# Processing Record 75 of Set 4 | birao
# Processing Record 76 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 77 of Set 4 | shingu
# Processing Record 78 of Set 4 | neiafu
# Processing Record 79 of Set 4 | dickinson
# Processing Record 80 of Set 4 | batesville
# Processing Record 81 of Set 4 | itarema
# Processing Record 82 of Set 4 | port augusta
# Processing Record 83 of Set 4 | souillac
# Processing Record 84 of Set 4 | sangar
# Processing Record 85 of Set 4 | champerico
# Processing Record 86 of Set 4 | kostino
# Processing Record 87 of Set 4 | abaete
# Processing Record 88 of Set 4 | vodstroy
# Processing Record 89 of Set 4 | yulara
# Processing Record 90 of Set 4 | sao felix do xingu
# Processing Record 91 of Set 4 | kaitangata
# Processing Record 92 of Set 4 | port lincoln
# Processing Record 93 of Set 4 | grindavik
# Processing Record 94 of Set 4 | boa vista
# Processing Record 95 of Set 4 | moree
# Processing Record 96 of Set 4 | huarmey
# Processing Record 97 of Set 4 | touros
# Processing Record 98 of Set 4 | mezen
# Processing Record 99 of Set 4 | tecoanapa
# Processing Record 100 of Set 4 | praia
# Processing Record 1 of Set 5 | aranos
# Processing Record 2 of Set 5 | lorengau
# Processing Record 3 of Set 5 | coihaique
# Processing Record 4 of Set 5 | casal di principe
# Processing Record 5 of Set 5 | bima
# Processing Record 6 of Set 5 | manoel urbano
# Processing Record 7 of Set 5 | koani
# Processing Record 8 of Set 5 | aksarka
# Processing Record 9 of Set 5 | hami
# Processing Record 10 of Set 5 | yaan
# Processing Record 11 of Set 5 | cap malheureux
# Processing Record 12 of Set 5 | mehamn
# Processing Record 13 of Set 5 | padang
# Processing Record 14 of Set 5 | doka
# Processing Record 15 of Set 5 | hare bay
# Processing Record 16 of Set 5 | doha
# Processing Record 17 of Set 5 | kautokeino
# Processing Record 18 of Set 5 | east london
# Processing Record 19 of Set 5 | ternate
# Processing Record 20 of Set 5 | wakkanai
# Processing Record 21 of Set 5 | edd
# Processing Record 22 of Set 5 | malartic
# Processing Record 23 of Set 5 | baicheng
# Processing Record 24 of Set 5 | half moon bay
# Processing Record 25 of Set 5 | willmar
# Processing Record 26 of Set 5 | bayir
# Processing Record 27 of Set 5 | salvador
# Processing Record 28 of Set 5 | isangel
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | darhan
# Processing Record 31 of Set 5 | ben tre
# Processing Record 32 of Set 5 | ust-omchug
# Processing Record 33 of Set 5 | miyazu
# Processing Record 34 of Set 5 | nanakuli
# Processing Record 35 of Set 5 | sao desiderio
# Processing Record 36 of Set 5 | vredefort
# Processing Record 37 of Set 5 | kaeng khlo
# City not found. Skipping...
# Processing Record 38 of Set 5 | imbituba
# Processing Record 39 of Set 5 | laureles
# Processing Record 40 of Set 5 | coahuayana
# Processing Record 41 of Set 5 | ishigaki
# Processing Record 42 of Set 5 | soubre
# Processing Record 43 of Set 5 | vostok
# Processing Record 44 of Set 5 | kloulklubed
# Processing Record 45 of Set 5 | okha
# Processing Record 46 of Set 5 | poitiers
# Processing Record 47 of Set 5 | freetown
# Processing Record 48 of Set 5 | northam
# Processing Record 49 of Set 5 | carutapera
# Processing Record 50 of Set 5 | sabang
# Processing Record 51 of Set 5 | maloy
# Processing Record 52 of Set 5 | la ronge
# Processing Record 53 of Set 5 | skvyra
# Processing Record 54 of Set 5 | pyaozerskiy
# Processing Record 55 of Set 5 | batemans bay
# Processing Record 56 of Set 5 | henties bay
# Processing Record 57 of Set 5 | cape canaveral
# Processing Record 58 of Set 5 | miranda
# Processing Record 59 of Set 5 | ponta do sol
# Processing Record 60 of Set 5 | tagusao
# Processing Record 61 of Set 5 | palm coast
# Processing Record 62 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 63 of Set 5 | salina cruz
# Processing Record 64 of Set 5 | kabare
# Processing Record 65 of Set 5 | rio verde de mato grosso
# Processing Record 66 of Set 5 | darab
# Processing Record 67 of Set 5 | pedasi
# Processing Record 68 of Set 5 | srednekolymsk
# Processing Record 69 of Set 5 | waling
# Processing Record 70 of Set 5 | karpuninskiy
# City not found. Skipping...
# Processing Record 71 of Set 5 | erzin
# Processing Record 72 of Set 5 | yarega
# Processing Record 73 of Set 5 | ahuimanu
# Processing Record 74 of Set 5 | sandviken
# Processing Record 75 of Set 5 | benghazi
# Processing Record 76 of Set 5 | savannakhet
# Processing Record 77 of Set 5 | marsa matruh
# Processing Record 78 of Set 5 | hofn
# Processing Record 79 of Set 5 | ilhabela
# Processing Record 80 of Set 5 | palmerston
# Processing Record 81 of Set 5 | kabo
# Processing Record 82 of Set 5 | senanga
# Processing Record 83 of Set 5 | sorokino
# Processing Record 84 of Set 5 | sao raimundo nonato
# Processing Record 85 of Set 5 | tessalit
# Processing Record 86 of Set 5 | narrabri
# Processing Record 87 of Set 5 | artyom
# Processing Record 88 of Set 5 | matara
# Processing Record 89 of Set 5 | palembang
# Processing Record 90 of Set 5 | polunochnoye
# Processing Record 91 of Set 5 | popondetta
# Processing Record 92 of Set 5 | nerchinskiy zavod
# Processing Record 93 of Set 5 | nuuk
# Processing Record 94 of Set 5 | bien hoa
# Processing Record 95 of Set 5 | marzuq
# Processing Record 96 of Set 5 | bullhead city
# Processing Record 97 of Set 5 | leningradskiy
# Processing Record 98 of Set 5 | seoul
# Processing Record 99 of Set 5 | sept-iles
# Processing Record 100 of Set 5 | yumen
# Processing Record 1 of Set 6 | sobolevo
# Processing Record 2 of Set 6 | hambantota
# Processing Record 3 of Set 6 | pokhara
# Processing Record 4 of Set 6 | orlik
# Processing Record 5 of Set 6 | ingham
# Processing Record 6 of Set 6 | guiyang
# Processing Record 7 of Set 6 | tura
# Processing Record 8 of Set 6 | porecatu
# Processing Record 9 of Set 6 | dakar
# Processing Record 10 of Set 6 | deshna
# City not found. Skipping...
# Processing Record 11 of Set 6 | amuntai
# Processing Record 12 of Set 6 | maniitsoq
# Processing Record 13 of Set 6 | mahajanga
# Processing Record 14 of Set 6 | kamaishi
# Processing Record 15 of Set 6 | bulawayo
# Processing Record 16 of Set 6 | dalaba
# Processing Record 17 of Set 6 | tongchuan
# Processing Record 18 of Set 6 | samarai
# Processing Record 19 of Set 6 | laurel
# Processing Record 20 of Set 6 | ocos
# Processing Record 21 of Set 6 | ondjiva
# Processing Record 22 of Set 6 | moron
# Processing Record 23 of Set 6 | yuza
# Processing Record 24 of Set 6 | ust-tsilma
# Processing Record 25 of Set 6 | aripuana
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | cururupu
# Processing Record 28 of Set 6 | haines junction
# Processing Record 29 of Set 6 | morehead
# Processing Record 30 of Set 6 | la lima
# Processing Record 31 of Set 6 | khandyga
# Processing Record 32 of Set 6 | aasiaat
# Processing Record 33 of Set 6 | tatawin
# Processing Record 34 of Set 6 | mabaruma
# Processing Record 35 of Set 6 | fort nelson
# Processing Record 36 of Set 6 | wageningen
# Processing Record 37 of Set 6 | faya
# Processing Record 38 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 39 of Set 6 | gwanda
# Processing Record 40 of Set 6 | valdivia
# Processing Record 41 of Set 6 | boca do acre
# Processing Record 42 of Set 6 | tobol
# Processing Record 43 of Set 6 | henzada
# City not found. Skipping...
# Processing Record 44 of Set 6 | tucuma
# Processing Record 45 of Set 6 | xining
# Processing Record 46 of Set 6 | bandarbeyla
# Processing Record 47 of Set 6 | neuquen
# Processing Record 48 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | te anau
# Processing Record 51 of Set 6 | bronte
# Processing Record 52 of Set 6 | sirjan
# Processing Record 53 of Set 6 | fairbanks
# Processing Record 54 of Set 6 | iranshahr
# Processing Record 55 of Set 6 | college
# Processing Record 56 of Set 6 | novouzensk
# Processing Record 57 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 58 of Set 6 | dalbandin
# Processing Record 59 of Set 6 | sirathu
# Processing Record 60 of Set 6 | baie-comeau
# Processing Record 61 of Set 6 | hanzhong
# Processing Record 62 of Set 6 | tiarei
# Processing Record 63 of Set 6 | elat
# Processing Record 64 of Set 6 | yerbogachen
# Processing Record 65 of Set 6 | belaya gora
# Processing Record 66 of Set 6 | kazerun
# Processing Record 67 of Set 6 | naze
# Processing Record 68 of Set 6 | makaha
# Processing Record 69 of Set 6 | shimoda
# Processing Record 70 of Set 6 | luderitz
# Processing Record 71 of Set 6 | atar
# Processing Record 72 of Set 6 | lae
# Processing Record 73 of Set 6 | oyama
# Processing Record 74 of Set 6 | santo antonio do sudoeste
# Processing Record 75 of Set 6 | kutno
# Processing Record 76 of Set 6 | rudbar
# Processing Record 77 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 78 of Set 6 | banff
# Processing Record 79 of Set 6 | oxford
# Processing Record 80 of Set 6 | tateyama
# Processing Record 81 of Set 6 | ambon
# Processing Record 82 of Set 6 | kailua
# Processing Record 83 of Set 6 | staryy nadym
# Processing Record 84 of Set 6 | matamoros
# Processing Record 85 of Set 6 | teya
# Processing Record 86 of Set 6 | margate
# Processing Record 87 of Set 6 | kincardine
# Processing Record 88 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 89 of Set 6 | soavinandriana
# Processing Record 90 of Set 6 | kalaiya
# Processing Record 91 of Set 6 | shelburne
# Processing Record 92 of Set 6 | biak
# Processing Record 93 of Set 6 | yarada
# Processing Record 94 of Set 6 | dunmore east
# Processing Record 95 of Set 6 | yinchuan
# Processing Record 96 of Set 6 | mineiros
# Processing Record 97 of Set 6 | baiao
# Processing Record 98 of Set 6 | kerva
# Processing Record 99 of Set 6 | nantucket
# Processing Record 100 of Set 6 | constantine
# Processing Record 1 of Set 7 | kemijarvi
# Processing Record 2 of Set 7 | ilulissat
# Processing Record 3 of Set 7 | topolobampo
# Processing Record 4 of Set 7 | sibolga
# Processing Record 5 of Set 7 | loandjili
# Processing Record 6 of Set 7 | kamenka
# Processing Record 7 of Set 7 | itanagar
# Processing Record 8 of Set 7 | mosalsk
# Processing Record 9 of Set 7 | aktas
# Processing Record 10 of Set 7 | kendari
# Processing Record 11 of Set 7 | hokitika
# Processing Record 12 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 7 | artigas
# Processing Record 15 of Set 7 | krasnoselkup
# Processing Record 16 of Set 7 | tunduma
# Processing Record 17 of Set 7 | llata
# Processing Record 18 of Set 7 | sibiti
# Processing Record 19 of Set 7 | la romana
# Processing Record 20 of Set 7 | wairoa
# Processing Record 21 of Set 7 | kalabo
# Processing Record 22 of Set 7 | kasama
# Processing Record 23 of Set 7 | massaguet
# Processing Record 24 of Set 7 | golspie
# Processing Record 25 of Set 7 | qandala
# Processing Record 26 of Set 7 | astoria
# Processing Record 27 of Set 7 | penzance
# Processing Record 28 of Set 7 | oistins
# Processing Record 29 of Set 7 | finnsnes
# Processing Record 30 of Set 7 | kununurra
# Processing Record 31 of Set 7 | poum
# Processing Record 32 of Set 7 | kuryk
# Processing Record 33 of Set 7 | sidi qasim
# City not found. Skipping...
# Processing Record 34 of Set 7 | san ramon
# Processing Record 35 of Set 7 | ketchikan
# Processing Record 36 of Set 7 | halifax
# Processing Record 37 of Set 7 | slyudyanka
# Processing Record 38 of Set 7 | pokanayevka
# City not found. Skipping...
# Processing Record 39 of Set 7 | black river
# Processing Record 40 of Set 7 | yuanping
# Processing Record 41 of Set 7 | vanimo
# Processing Record 42 of Set 7 | dandong
# Processing Record 43 of Set 7 | vieques
# Processing Record 44 of Set 7 | winnemucca
# Processing Record 45 of Set 7 | brae
# Processing Record 46 of Set 7 | san juan de la maguana
# Processing Record 47 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 7 | victor harbor
# Processing Record 49 of Set 7 | honningsvag
# Processing Record 50 of Set 7 | qingyuan
# Processing Record 51 of Set 7 | vrangel
# Processing Record 52 of Set 7 | mopti
# Processing Record 53 of Set 7 | jati
# Processing Record 54 of Set 7 | vernon
# Processing Record 55 of Set 7 | kaseda
# Processing Record 56 of Set 7 | ostersund
# Processing Record 57 of Set 7 | nisia floresta
# Processing Record 58 of Set 7 | vallenar
# Processing Record 59 of Set 7 | labuhan
# Processing Record 60 of Set 7 | thinadhoo
# Processing Record 61 of Set 7 | margherita
# Processing Record 62 of Set 7 | lazaro cardenas
# Processing Record 63 of Set 7 | inta
# Processing Record 64 of Set 7 | pahrump
# Processing Record 65 of Set 7 | gushikawa
# Processing Record 66 of Set 7 | sompeta
# Processing Record 67 of Set 7 | ucluelet
# Processing Record 68 of Set 7 | plainview
# Processing Record 69 of Set 7 | dhidhdhoo
# Processing Record 70 of Set 7 | nuevitas
# Processing Record 71 of Set 7 | navolato
# Processing Record 72 of Set 7 | vygonichi
# Processing Record 73 of Set 7 | bell ville
# Processing Record 74 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 75 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 76 of Set 7 | bokoro
# Processing Record 77 of Set 7 | amboasary
# Processing Record 78 of Set 7 | pishva
# Processing Record 79 of Set 7 | bowen
# Processing Record 80 of Set 7 | tahoua
# Processing Record 81 of Set 7 | tunceli
# Processing Record 82 of Set 7 | zhangye
# Processing Record 83 of Set 7 | quatre cocos
# Processing Record 84 of Set 7 | lubbock
# Processing Record 85 of Set 7 | salinopolis
# Processing Record 86 of Set 7 | coxim
# Processing Record 87 of Set 7 | rabo de peixe
# Processing Record 88 of Set 7 | kotri
# Processing Record 89 of Set 7 | norden
# Processing Record 90 of Set 7 | lincoln
# Processing Record 91 of Set 7 | gao
# Processing Record 92 of Set 7 | nsanje
# Processing Record 93 of Set 7 | lamu
# Processing Record 94 of Set 7 | petersburg
# Processing Record 95 of Set 7 | epe
# Processing Record 96 of Set 7 | umm lajj
# Processing Record 97 of Set 7 | kiama
# Processing Record 98 of Set 7 | roswell
# Processing Record 99 of Set 7 | santa catalina
# Processing Record 100 of Set 7 | ca mau
# Processing Record 1 of Set 8 | juegang
# Processing Record 2 of Set 8 | mehran
# Processing Record 3 of Set 8 | handan
# Processing Record 4 of Set 8 | pochutla
# Processing Record 5 of Set 8 | general pico
# Processing Record 6 of Set 8 | mulchen
# Processing Record 7 of Set 8 | shahr-e kord
# Processing Record 8 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 8 | chuguyevka
# Processing Record 10 of Set 8 | hoquiam
# Processing Record 11 of Set 8 | treinta y tres
# Processing Record 12 of Set 8 | mogzon
# Processing Record 13 of Set 8 | kerema
# Processing Record 14 of Set 8 | quepos
# Processing Record 15 of Set 8 | asfi
# Processing Record 16 of Set 8 | udachnyy
# Processing Record 17 of Set 8 | warri
# Processing Record 18 of Set 8 | south venice
# Processing Record 19 of Set 8 | lixourion
# Processing Record 20 of Set 8 | knysna
# Processing Record 21 of Set 8 | qui nhon
# Processing Record 22 of Set 8 | roald
# Processing Record 23 of Set 8 | vila
# Processing Record 24 of Set 8 | ouadda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692     76.24        77           0
# 1      New Norfolk -42.7826  147.0587     83.75        25         100
# 2             Fare -16.7000 -151.0167     81.55        74         100
# 3          Ushuaia -54.8000  -68.3000     55.06        44          40
# 4       Vila Velha -20.3297  -40.2925     75.15        93          90
# 5         Anupgarh  29.1911   73.2086     71.02        24          99
# 6  Arraial Do Cabo -22.9661  -42.0278     73.45        91          98
# 7           Hobart -42.8794  147.3294     84.11        38          75
# 8          Aklavik  68.2191 -135.0107    -22.97        99          60
# 9           Barrow  71.2906 -156.7887    -16.58        69           1
#
#    Wind Speed Country Weather Description                 Date
# 0       21.47      PF          light rain  2021-12-01 03:45:26
# 1        1.99      AU     overcast clouds  2021-12-01 03:45:27
# 2       19.71      PF          light rain  2021-12-01 03:41:53
# 3       17.27      AR    scattered clouds  2021-12-01 03:45:28
# 4        8.01      BR                mist  2021-12-01 03:41:23
# 5        3.24      IN     overcast clouds  2021-12-01 03:45:29
# 6        6.82      BR     overcast clouds  2021-12-01 03:45:30
# 7       11.50      AU        thunderstorm  2021-12-01 03:45:30
# 8        4.27      CA       broken clouds  2021-12-01 03:45:31
# 9       12.66      US           clear sky  2021-12-01 03:43:04

# %%
new_order = ["City", "Country","Lat", "Lng" ,"Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_df = city_data_df[new_order]
city_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     76.24        77           0
# 1      New Norfolk      AU -42.7826  147.0587     83.75        25         100
# 2             Fare      PF -16.7000 -151.0167     81.55        74         100
# 3          Ushuaia      AR -54.8000  -68.3000     55.06        44          40
# 4       Vila Velha      BR -20.3297  -40.2925     75.15        93          90
# 5         Anupgarh      IN  29.1911   73.2086     71.02        24          99
# 6  Arraial Do Cabo      BR -22.9661  -42.0278     73.45        91          98
# 7           Hobart      AU -42.8794  147.3294     84.11        38          75
# 8          Aklavik      CA  68.2191 -135.0107    -22.97        99          60
# 9           Barrow      US  71.2906 -156.7887    -16.58        69           1
#
#    Wind Speed Weather Description
# 0       21.47          light rain
# 1        1.99     overcast clouds
# 2       19.71          light rain
# 3       17.27    scattered clouds
# 4        8.01                mist
# 5        3.24     overcast clouds
# 6        6.82     overcast clouds
# 7       11.50        thunderstorm
# 8        4.27       broken clouds
# 9       12.66           clear sky

# %%
Weather_database_save = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(Weather_database_save,index_label="City_ID")
